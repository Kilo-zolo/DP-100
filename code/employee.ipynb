# %%
import pandas as pd

# %%
# Read CSV files from azure blob storage (zohds/datasets-ml)
df_AC1 = pd.read_csv("https://zohds.blob.core.windows.net/datasets-ml/Employee%20Dataset%20-%20AC1.csv?sp=r&st=2022-10-30T07:19:39Z&se=2022-10-30T15:19:39Z&sv=2021-06-08&sr=b&sig=McEDz0Y3GMv5pqD%2FNPXwlIF%2FRvUymIYYgmcI3uoTTmA%3D")
df_AC2 = pd.read_csv("https://zohds.blob.core.windows.net/datasets-ml/Employee%20Dataset%20-%20AC2.csv?sp=r&st=2022-10-30T07:20:58Z&se=2022-10-30T15:20:58Z&sv=2021-06-08&sr=b&sig=ckpg4TE5QldywF0xXRJSo0I4RUgMityhZW2pNYvxSgE%3D")

# %%
# View first 5 rows of df_AC1
df_AC1.head()
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
#
#    Gender Marital Status  Monthly Income
# 0    Male         Single            5993
# 1    Male        Married            5130
# 2    Male         Single            2090
# 3  Female        Married            2909
# 4    Male        Married            3468

# %%
# View first 5 rows of df_AC2
df_AC2.head()
# Out:
#    Years of Experience  Percent Salary Hike  Performance Rating
# 0                    8                   11                   3
# 1                    1                   23                   4
# 2                    6                   15                   3
# 3                    1                   11                   3
# 4                    9                   12                   3

# %%
# Join df_Ac1 and df_AC2 with each other and make one whole df
df_AC = df_AC1.join(df_AC2)
df_AC.head()
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0    Male         Single            5993                    8
# 1    Male        Married            5130                    1
# 2    Male         Single            2090                    6
# 3  Female        Married            2909                    1
# 4    Male        Married            3468                    9
#
#    Percent Salary Hike  Performance Rating
# 0                   11                   3
# 1                   23                   4
# ...

# %%
df_AR1 = pd.read_csv("https://zohds.blob.core.windows.net/datasets-ml/Employee%20Dataset%20-%20AR1.csv?sp=r&st=2022-10-30T07:26:48Z&se=2022-10-30T15:26:48Z&sv=2021-06-08&sr=b&sig=vdcvmBZ3GSQbzRwWJS4EDfh4%2Bzzm78vwZ%2FM%2B1TCiv%2BM%3D")
df_AR2 = pd.read_csv("https://zohds.blob.core.windows.net/datasets-ml/Employee%20Dataset%20-%20AR2.csv?sp=r&st=2022-10-30T07:28:49Z&se=2022-10-30T15:28:49Z&sv=2021-06-08&sr=b&sig=dw8Oulm2zWOkazYHWhAg2yL3i1JiDwNjeKbqacxlR9g%3D")

# %%
df_AR1.head()
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        Jitesh   41       31-12-9999              Training        Masters
# 1        Sanjit   49       31-12-9999                 Sales        Masters
# 2          John   37       31-12-9999                   R&D      Doctorate
# 3        Sandra   33       31-12-9999  Software Development  Undergraduate
# 4         Madhu   27       31-12-9999                   R&D        Masters
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0    Male         Single            5993                    8
# 1    Male        Married            5130                    1
# 2    Male         Single            2090                    6
# 3  Female        Married            2909                    1
# 4    Male        Married            3468                    9
#
#    Percent Salary Hike  Performance Rating
# 0                   11                   3
# 1                   23                   4
# ...

# %%
df_AR2.head()
# Out:
#   Employee Name  Age Last Working Day            Department      Education  \
# 0        George   36       31-12-9999  Software Development        Masters
# 1          Adam   35       31-12-9999  Software Development        Masters
# 2          Adam   35       31-12-9999  Software Development        Masters
# 3          Adam   35       31-12-9999  Software Development        Masters
# 4          Emma   29       31-12-9999  Software Development  Undergraduate
#
#    Gender Marital Status  Monthly Income  Years of Experience  \
# 0     NaN        Married            5237                    6
# 1    Male        Married            2426                    0
# 2    Male        Married            2426                    0
# 3    Male        Married            2426                    0
# 4  Female         Single            4193                    0
#
#    Percent Salary Hike  Performance Rating
# 0                   13                   3
# 1                   13                   3
# ...

# %%
df_AR = pd.concat([df_AR1, df_AR2], ignore_index = True)
