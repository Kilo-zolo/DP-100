# %%
# Import Workspace
from azureml.core import Workspace

# %%
# Create the Workspace

ws = Workspace.create(name= 'azml-samp-ws',
                      subscription_id= 'd49e9a5f-2f5d-4831-9c2d-5190b641fad6',
                      resource_group= 'dp100rg',
                      create_resource_group=True,
                      location='AustraliaEast'
)
# Out:
# ...
# Deploying KeyVault with name azmlsampkeyvaultd98de703.
# Deploying AppInsights with name azmlsampinsightsa731c3b1.
# Deployed AppInsights with name azmlsampinsightsa731c3b1. Took 7.04 seconds.
# Deploying StorageAccount with name azmlsampstoragef8831c35c.
# Deployed KeyVault with name azmlsampkeyvaultd98de703. Took 20.17 seconds.
# Deploying Workspace with name azml-samp-ws.
# Deployed StorageAccount with name azmlsampstoragef8831c35c. Took 47.61 seconds.
# Deployed Workspace with name azml-samp-ws. Took 35.08 seconds.

# %%
# Write config file to provided path
ws.write_config("/Users/Krish/dev/DP-100/config")
