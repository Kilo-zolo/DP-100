# %%
# Import necessary modules from azureml-sdk library
from azureml.core import Workspace, Datastore, Dataset

# %%
# Import pre-made workspace from config file
ws = Workspace.from_config("/Users/Krish/dev/DP-100/config/azml-samp-config.json")

# %%
# List all workspaces within a subscription
wsl = Workspace.list(subscription_id="d49e9a5f-2f5d-4831-9c2d-5190b641fad6",
                    resource_group="azmlsdk-samp-rg1")

# %%
# Access default datastore from workspace
def_dstore = ws.get_default_datastore()

# %%
# List all datastores 
dstorel = list(ws.datastores)

# %%
# List all datsets within a workspace
dsetl = list(ws.datasets.keys())

# %%
# Create a for loop to print all items within the dataset list var made above
for i in dsetl:
    print(i)
# Out:
# Loan Dataset From Dataframe
# Loan App sdk

# %%
# Get access to dataset/datasets within a workspace 
dset = Dataset.get_by_name(ws, "Loan App sdk")

# %%
# Load the Azureml Dataset into the pandas dataframe
dframe = dset.to_pandas_dataframe()
dframe.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male   False          0      Graduate         False
# 1  LP001003   Male    True          1      Graduate         False
# 2  LP001005   Male    True          0      Graduate          True
# 3  LP001006   Male    True          0  Not Graduate         False
# 4  LP001008   Male   False          0      Graduate         False
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# 0             1.0         Urban         True
# 1             1.0         Rural        False
# ...

# %%
# Upload the dataframe to azureml dataset
dframe_test = dframe[["Married","Gender","Loan_Status"]]
az_dset_from_dframe = Dataset.Tabular.register_pandas_dataframe(dataframe= dframe_test,
                                                                target=def_dstore,
                                                                name= "Loan Dataset From Dataframe")
# Out:
# Validating arguments.
# Arguments validated.
# Successfully obtained datastore reference and path.
# Uploading file to managed-dataset/6d67809d-5924-45ae-8f08-823ac1ce4708/
# Successfully uploaded file to datastore.
# Creating and registering a new dataset.
# Successfully created and registered a new dataset.

# %%
# Create a list of local files by adding their local paths to a list
fl = ['/Users/Krish/uni_bach/sem2_2022/Equty and investment/Assignment 3/Equity Trading Logbook Sem 2 2022-1.xlsx']
# Upload the list of files to azure datastore of your choice
def_dstore.upload_files(files= fl, 
                        target_path = "Loan Data/",
                        relative_root= "/Users/Krish/uni_bach/sem2_2022/Equty and investment/Assignment 3/",
                        overwrite= True)
# Out:
# "datastore.upload_files" is deprecated after version 1.0.69. Please use "FileDatasetFactory.upload_directory" instead. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# Uploading an estimated of 1 files
# Uploading /Users/Krish/uni_bach/sem2_2022/Equty and investment/Assignment 3/Equity Trading Logbook Sem 2 2022-1.xlsx
# Uploaded /Users/Krish/uni_bach/sem2_2022/Equty and investment/Assignment 3/Equity Trading Logbook Sem 2 2022-1.xlsx, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_d60ca208240d4f9a90d56e382be39a3f

# %%
# Upload an entire directory/folder to azure datastore
def_dstore.upload(src_dir="/Users/Krish/stream/",
                  target_path="test/data",
                  overwrite = True)
# Out:
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.
# Uploading an estimated of 4 files
# Uploading /Users/Krish/stream/.DS_Store
# Uploaded /Users/Krish/stream/.DS_Store, 1 files out of an estimated total of 4
# Uploading /Users/Krish/stream/scenes/.DS_Store
# Uploaded /Users/Krish/stream/scenes/.DS_Store, 2 files out of an estimated total of 4
# Uploading /Users/Krish/stream/scenes/Scene_Intermission1.png
# Uploaded /Users/Krish/stream/scenes/Scene_Intermission1.png, 3 files out of an estimated total of 4
# Uploading /Users/Krish/stream/scenes/Scene_Starting1.png
# Uploaded /Users/Krish/stream/scenes/Scene_Starting1.png, 4 files out of an estimated total of 4
# Uploaded 4 files
# $AZUREML_DATAREFERENCE_b578c85ba82b4f5c9d926a2bf396fc28
